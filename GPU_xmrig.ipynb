# %%
# !sudo apt-get update

# %%
# !sudo apt-get install git build-essential cmake libuv1-dev libssl-dev libhwloc-dev

# %%
# !git clone https://github.com/xmrig/xmrig.git

# %%
cd xmrig

# %%
mkdir build

# %%
cd build

# %%
# !cmake ..

# %%
# !make

# %%
cd ..

# %%
cd ..

# %%
# !git clone https://github.com/xmrig/xmrig-cuda.git

# %%
cd xmrig-cuda

# %%
# !cmake .

# %%
# !make

# %%
cd ..

# %%
cd xmrig

# %%
cd build

# %%
cp /content/xmrig-cuda/libxmrig-cuda.so .

# %%
cp /content/xmrig-cuda/libxmrig-cu.a .

# %%
# !./xmrig --donate-level 1 --cuda --cuda-loader=./libxmrig-cuda.so -o xmr.hashcity.org:4444 -u starlon.[WORKER] -p x -a rx/0
